# %% [markdown]
# <a href="https://colab.research.google.com/github/menacingrabbit/google-colab-2/blob/colab-test/Relaxing_Reggae_Beach_Video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Please ensure you have imported a Gemini API key from AI Studio.
# You can do this directly in the Secrets tab on the left.
#
# After doing so, please run the setup cell below.

# %%
# !pip install -U -q "google-generativeai"

import os
from google.colab import userdata

os.environ["GEMINI_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %% [markdown]
# # Generated Code

# %%
# To run this code you need to install the following dependencies:
# pip install google-genai

from google import genai
import os

def generate():
    client = genai.Client(api_key=os.environ.get("GEMINI_API_KEY"))

    result = client.models.generate_images(
        model="models/imagen-4.0-ultra-generate-preview-06-06",
        prompt="""YouTube thumbnail for a relaxing reggae music video mix: on the left side, featuring a realistic photograph of beautiful woman with beach attire and fit flat belly visible
           at a beach bar with party in the background and a title in reggae-insprired colours on the right side merging into a seamless picture together""",
        config=dict(
            number_of_images=1,
            output_mime_type="image/jpeg",
            person_generation="ALLOW_ADULT",
            aspect_ratio="16:9",
        ),
    )

    if not result.generated_images:
        print("No images generated.")
        return

    if len(result.generated_images) != 1:
        print("Number of images generated does not match the requested number.")

    for generated_image in result.generated_images:
        image = generated_image.image.show()

if __name__ == "__main__":
    generate()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1408x768>
